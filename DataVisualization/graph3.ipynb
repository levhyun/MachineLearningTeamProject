# %%
import pandas as pd
import matplotlib.pyplot as plt

criminalTimeTop10 = pd.read_csv('.\data\criminalTimeTop10.csv')
criminalTimeTop10
# Out:
#   범죄중분류  21:00 ~ 23:59  18:00 ~ 20:59  15:00 ~ 17:59  09:00 ~ 11:59  \
# 0  교통범죄          70537          58164          53506          44265
# 1    절도          20568          27229          28553          21501
# 2    폭행          34120          20704          14791          11591
# 3    사기          12387          13930          21648          39184
#
#    12:00 ~ 14:59  0:00 ~ 02:59  06:00 ~ 08:59  03:00 ~ 05:59
# 0          45675         24513          37189          23438
# 1          27167         13088          13094          14167
# 2          12509         19226           9345          16377
# 3          30405          5443           3056           3949

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.15
index = np.arange(len(list(criminalTimeTop10.columns)[1:]))

b1 = plt.bar(index - bar_width, list(criminalTimeTop10.loc[index[0]])[1:], width=bar_width, alpha=0.4, color='red', label=criminalTimeTop10.loc[index[0], ['범죄중분류']][0])
b2 = plt.bar(index, list(criminalTimeTop10.loc[index[1]])[1:], width=bar_width, alpha=0.4, color='orange', label=criminalTimeTop10.loc[index[1], ['범죄중분류']][0])
b3 = plt.bar(index + bar_width, list(criminalTimeTop10.loc[index[2]])[1:], width=bar_width, alpha=0.4, color='yellow', label=criminalTimeTop10.loc[index[2], ['범죄중분류']][0])
b4 = plt.bar(index + 2 * bar_width, list(criminalTimeTop10.loc[index[3]])[1:], width=bar_width, alpha=0.4, color='green', label=criminalTimeTop10.loc[index[3], ['범죄중분류']][0])

plt.xticks(index, list(criminalTimeTop10.columns)[1:])

plt.xlabel('장소', size=13)
plt.ylabel('범죄 건수', size=13)
plt.title('시간별 범죄', size=13)
plt.legend()
plt.show()
